# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.manifold import TSNE
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import seaborn as sns

# %% [markdown]
# ## 1) Loading Data:

# %%
df = pd.read_csv(r"..\Dados\Tabela_final\tabela_final_edu.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 63 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   IBGE7                1170 non-null   int64
#  1   UF                   1170 non-null   object
#  2   NOME                 1170 non-null   object
#  3   LATITUDE             1170 non-null   float64
#  4   LONGITUDE            1170 non-null   float64
#  5   DIST_EF_PUB          1170 non-null   float64
#  6   DIST_EM_PUB          1170 non-null   float64
#  7   IDEB_AI              1170 non-null   float64
#  8   IDEB_AF              1170 non-null   float64
#  9   DOCSUP_EF_PUB        1170 non-null   float64
#  10  DOCSUP_EM_PUB        1170 non-null   float64
#  11  TXNASC7C             1170 non-null   float64
#  12  TXNBAIXOP            1170 non-null   float64
#  13  PINTERSAP            1170 non-null   float64
#  14  PINTERDRSAI          1170 non-null   float64
#  15  REN_PIBPC_D          1170 non-null   float64
#  16  PDEFAGUA             1170 non-null   float64
#  17  PDEFESGOTO           1170 non-null   float64
#  18  PANALF15             1170 non-null   float64
#  19  PIND_POS             1170 non-null   float64
#  20  SNIS_PAGUA           1170 non-null   float64
#  21  POP_TOT              1170 non-null   float64
#  22  POP_TOT_30KM         1170 non-null   float64
#  23  PREC_MED             1170 non-null   float64
#  24  TEMP_MED             1170 non-null   float64
#  25  AREA_IRRIGADA_TOT    1170 non-null   float64
#  26  AREA_IRRIGADA_POT    1170 non-null   float64
#  27  AREA_IRRIGADA_POT_E  1170 non-null   float64
#  28  IDHM                 1170 non-null   float64
#  29  T_BANAGUA            1170 non-null   float64
#  30  T_DENS               1170 non-null   float64
#  31  T_LIXO               1170 non-null   float64
#  32  T_LUZ                1170 non-null   float64
#  33  AGUA_ESGOTO          1170 non-null   float64
#  34  PAREDE               1170 non-null   float64
#  35  PIND                 1170 non-null   float64
#  36  PINDCRI              1170 non-null   float64
#  37  T_DES18M             1170 non-null   float64
#  38  T_FBBAS              1170 non-null   float64
#  39  T_FBFUND             1170 non-null   float64
#  40  T_FBMED              1170 non-null   float64
#  41  T_FBPRE              1170 non-null   float64
#  42  T_FBSUPER            1170 non-null   float64
#  43  T_ATRASO_1_BASICO    1170 non-null   float64
#  44  T_ATRASO_1_FUND      1170 non-null   float64
#  45  T_ATRASO_1_MED       1170 non-null   float64
#  46  T_ATRASO_2_BASICO    1170 non-null   float64
#  47  T_ATRASO_2_FUND      1170 non-null   float64
#  48  T_ATRASO_2_MED       1170 non-null   float64
#  49  T_ANALF11A14         1170 non-null   float64
#  50  T_ANALF15A17         1170 non-null   float64
#  51  T_ANALF15M           1170 non-null   float64
#  52  T_ANALF18A24         1170 non-null   float64
#  53  T_ANALF18M           1170 non-null   float64
#  54  T_ANALF25A29         1170 non-null   float64
#  55  T_ANALF25M           1170 non-null   float64
#  56  QUAL_MED_AGUA        1170 non-null   float64
#  57  DIST_CORPO_AGUA      1170 non-null   float64
#  58  TRANSPORT_COST       1170 non-null   float64
#  59  TOT_ESC_POR_POP      1170 non-null   float64
#  60  TOT_MAT_POR_POP      1170 non-null   float64
#  61  PMATPUB_EF           1170 non-null   float64
#  62  PMATPUB_EM           1170 non-null   float64
# dtypes: float64(60), int64(1), object(2)
# memory usage: 576.0+ KB

# %%
lista_colunas = [coluna for coluna in df.columns if (df[coluna].dtype == 'float64')&(coluna not in ['LATITUDE', 'LONGITUDE'])]

# %%
#df_final_merged = df[lista_colunas]

# %%
df_final_merged = pd.read_csv(r"..\Dados\Tabela_final\df_selecionado_cluster.csv")

# %%
df_final_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1170 entries, 0 to 1169
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   DIST_EF_PUB        1170 non-null   float64
#  1   DIST_EM_PUB        1170 non-null   float64
#  2   IDEB_AI            1170 non-null   float64
#  3   IDEB_AF            1170 non-null   float64
#  4   DOCSUP_EF_PUB      1170 non-null   float64
#  5   DOCSUP_EM_PUB      1170 non-null   float64
#  6   TXNASC7C           1170 non-null   float64
#  7   REN_PIBPC_D        1170 non-null   float64
#  8   PDEFAGUA           1170 non-null   float64
#  9   PDEFESGOTO         1170 non-null   float64
#  10  PANALF15           1170 non-null   float64
#  11  PIND_POS           1170 non-null   float64
#  12  POP_TOT_30KM       1170 non-null   float64
#  13  IDHM               1170 non-null   float64
#  14  T_BANAGUA          1170 non-null   float64
#  15  T_DENS             1170 non-null   float64
#  16  T_LUZ              1170 non-null   float64
#  17  AGUA_ESGOTO        1170 non-null   float64
#  18  PIND               1170 non-null   float64
#  19  PINDCRI            1170 non-null   float64
#  20  T_FBBAS            1170 non-null   float64
#  21  T_FBFUND           1170 non-null   float64
#  22  T_FBPRE            1170 non-null   float64
#  23  T_FBSUPER          1170 non-null   float64
#  24  T_ATRASO_1_BASICO  1170 non-null   float64
#  25  T_ATRASO_1_FUND    1170 non-null   float64
#  26  T_ATRASO_1_MED     1170 non-null   float64
#  27  T_ATRASO_2_BASICO  1170 non-null   float64
#  28  T_ATRASO_2_FUND    1170 non-null   float64
#  29  T_ATRASO_2_MED     1170 non-null   float64
#  30  T_ANALF11A14       1170 non-null   float64
#  31  T_ANALF15A17       1170 non-null   float64
#  32  T_ANALF15M         1170 non-null   float64
#  33  T_ANALF18A24       1170 non-null   float64
#  34  T_ANALF18M         1170 non-null   float64
#  35  T_ANALF25A29       1170 non-null   float64
#  36  T_ANALF25M         1170 non-null   float64
#  37  DIST_CORPO_AGUA    1170 non-null   float64
#  38  TOT_ESC_POR_POP    1170 non-null   float64
#  39  PMATPUB_EF         1170 non-null   float64
# dtypes: float64(40)
# memory usage: 365.8 KB

# %% [markdown]
# ## 2) Preprocessamento

# %% [markdown]
# ### 2.1) Scalling

# %% [markdown]
# #### 2.1.1) StandardScaler

# %%
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_final_merged)

# %%
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = df_final_merged.columns

# %% [markdown]
# ### 2.2) Dimensionality Reduction

# %% [markdown]
# #### 2.2.1) PCA

# %%
pca = PCA(n_components=0.95)
df_pca = pca.fit_transform(df_scaled)

# %%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)
# Crie um gráfico para visualizar o acúmulo de variância
plt.figure(figsize=(8, 6))
plt.plot(cumulative_variance, marker='o', linestyle='-')
print("Número de componentes para 0.95 de variância:", df_pca.shape[1])
plt.xlabel('Número de Componentes Principais')
plt.ylabel('Variância Acumulada Explicada')
plt.title('Acúmulo de Variância por Número de Componentes Principais')
plt.grid(True)
plt.show()
# Out:
# Número de componentes para 0.95 de variância: 24

# %% [markdown]
# #### 2.2.2) T-SNE

# %%
def plot_clusters(df, df_components, clusters):
    df[['COMPONENT1', 'COMPONENT2']] = df_components
    df['CLUSTER'] = clusters

    actual_cities = df[['NOME', 'COMPONENT1', 'COMPONENT2', 'CLUSTER']].loc[df['NOME'].isin(['MAURITI', 'SÃO JOSÉ DA TAPERA', 'BUÍQUE', 'INAJÁ'])]

    print(actual_cities)
    plt.figure(figsize=(8, 6))
    sns.scatterplot(data=df, x='COMPONENT1', y='COMPONENT2', hue='CLUSTER', palette='Set2')
    sns.scatterplot(data=actual_cities, x='COMPONENT1', y='COMPONENT2', marker = 'X', color='black', s=100, label='Cidades atuais')
    for i, row in actual_cities.iterrows():
        plt.text(row['COMPONENT1'] + 0.1, row['COMPONENT2'], row['NOME'], fontsize=12)
    plt.xlabel('Componente 1')
    plt.ylabel('Componente 2')
    plt.title('Visualização dos Clusters')
    plt.legend(title='Cluster', loc='upper right')
    plt.grid(True)
    plt.show()

# %%
tsne = TSNE(n_components=2, random_state=42)
df_components = tsne.fit_transform(df_pca)

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### 2.3) Kmeans:

# %% [markdown]
# #### 2.3.1) Elbow curve

# %%
model = KMeans(n_init=20, random_state=42)
visualizer = KElbowVisualizer(model, k=(4,20))
visualizer.fit(df_pca)        # Fit the data to the visualizer
visualizer.show();        # Finalize and render the figure

# %% [markdown]
# #### 2.3.2) Silhouette_score

# %%
def best_silhuet_score(data):
    best_silhuet = 0
    best_k = 0
    for i in range(2, 21):
        kmean = KMeans(n_clusters=i, n_init=20, random_state=42)
        centroids = kmean.fit_transform(df_pca)
        score = silhouette_score(df_pca, kmean.labels_)
        if score > best_silhuet:
            best_silhuet = score
            best_k = i
        
    return best_k, best_silhuet

# %%
best_k, best_silhuet = best_silhuet_score(df_pca)

# %%
kmean = KMeans(n_clusters=best_k, n_init=20, random_state=42)
visualizer = SilhouetteVisualizer(kmean, colors="yellowbrick")
visualizer.fit(df_pca)
visualizer.show();
print("Silhouette avg:", visualizer.silhouette_score_)
# Out:
# Silhouette avg: 0.15645912399125558

# %% [markdown]
# #### 2.3.3) Métricas finais:

# %%
kmeans = KMeans(best_k, random_state = 42, n_init=20)
clusters = kmeans.fit_predict(df_pca)
print('Silhouette Score: ',round(silhouette_score(df_pca, clusters), 4))
print('Davies-Bouldin Score: ',round(davies_bouldin_score(df_pca, clusters), 4))
print('Calinski-Harabasz Index: ',round(calinski_harabasz_score(df_pca, clusters), 4))
plot_clusters(df, df_components, clusters)
# Out:
# Silhouette Score:  0.1565
# Davies-Bouldin Score:  2.0465
# Calinski-Harabasz Index:  261.9132
#                    NOME  COMPONENT1  COMPONENT2  CLUSTER
# 34   SÃO JOSÉ DA TAPERA  -30.952539   -3.482690        0
# 418             MAURITI   15.650069  -17.092205        1
# 705              BUÍQUE  -31.620108   -4.968064        0
# 736               INAJÁ  -33.731316   -6.339488        0

# %% [markdown]
# Como o Kmeans foi satisfatório deviso as suas métricas, iremos utilizar suas labels para treinar um modelo de classificação e, com isto, observar quais são as features mais relevantes para a clusterização

# %%
#df_final_maci['Labels'] = kmeans.labels_

# %%
#df_final_maci.to_csv(r"..\Dados\Tabela_final\tabela_final_com_cluster.csv", index=False)

# %% [markdown]
# ### 2.4) Hirarchical clustering:

# %%
linkage_matrix = linkage(df_pca, method='ward')

plt.figure()
dendrogram(linkage_matrix)
plt.title('Dendrograma')
plt.xticks([])
plt.xlabel('Índice dos Pontos')
plt.ylabel('Distância')
plt.show()

# %%
hclustering = AgglomerativeClustering(n_clusters=5)
clusters = hclustering.fit_predict(df_pca)
print('Silhouette Score: ',round(silhouette_score(df_pca, clusters),4))
print('Davies-Bouldin Score: ',round(davies_bouldin_score(df_pca, clusters),4))
print('Calinski-Harabasz Index: ',round(calinski_harabasz_score(df_pca, clusters),4))
plot_clusters(df, df_components, clusters)
# Out:
# Silhouette Score:  0.062
# Davies-Bouldin Score:  2.7276
# Calinski-Harabasz Index:  112.3749
#                    NOME  COMPONENT1  COMPONENT2  CLUSTER
# 34   SÃO JOSÉ DA TAPERA  -30.952539   -3.482690        2
# 418             MAURITI   15.650069  -17.092205        4
# 705              BUÍQUE  -31.620108   -4.968064        2
# 736               INAJÁ  -33.731316   -6.339488        2
